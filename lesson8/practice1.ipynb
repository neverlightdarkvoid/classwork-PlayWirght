# %%
try:
    money = int(input("請輸入金額:"))
    print(f"輸入的金額是{money}") #f"string"
except ValueError as e:
    print(f"輸入錯誤:{e}")
# Out:
# 請輸入金額: ARE
# 輸入錯誤:invalid literal for int() with base 10: 'ARE'
